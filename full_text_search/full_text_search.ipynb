# %% [markdown]
# ## Full Text Search
# This notebook shows how to use the API's search functionality

# %%
import requests
from collections import OrderedDict

keyword = "turkey"

starting_url = 'https://api.case.law/v1/cases/?search=' + keyword

jurisdictions = {}
results_count = 0

# %%
def get_pages(url):
    while True:
        result = requests.get(url).json()
        yield result
        url = result['next']
        if not url:
            break

def get_results(url):
    for page in get_pages(url):
        for result in page['results']:
            yield result

for case in get_results(starting_url):
    results_count += 1

    id = case['id']
    name = case['name_abbreviation']
    jurisdiction = case['jurisdiction']['name']
    date = case['decision_date']
    url = case['url']

    if jurisdiction not in jurisdictions:
        jurisdictions[jurisdiction] = {'name': jurisdiction, 'count': 1, 'oldest_case_id': id,
                                       'oldest_case_name': name, 'oldest_case_date': date, 'oldest_case_url': url}

    else:
        new_count = jurisdictions[jurisdiction]['count'] + 1
        if jurisdictions[jurisdiction]['oldest_case_date'] > date:
            jurisdictions[jurisdiction] = {'name': jurisdiction, 'count': new_count, 'oldest_case_id': id,
                                           'oldest_case_name': name, 'oldest_case_date': date,
                                           'oldest_case_url': url}

print('Results for keyword: ' + keyword)
print('Total cases: ' + str(results_count))
# Out:
# Results for keyword: turkey
# Total cases: 18948

# %%
results_sorted = OrderedDict(sorted(jurisdictions.items(), key=lambda kv: kv[1]['oldest_case_date']))
print('Jurisdiction-by-Jurisdiction Results' + '\n')

for values in results_sorted.values():
    print(values['name'] + ': ' + str(values['count']))
    print('Oldest case: ' + values['oldest_case_name'] + '(' + values['oldest_case_date'] + ')')
    print('Link: ' + values['oldest_case_url'])
    print('\n')
# Out:
# Jurisdiction-by-Jurisdiction Results
#
# Mass.: 7
# Oldest case: Briggs v. Leverett(1675-07-27)
# Link: https://api.case.law/v1/cases/12070732/
#
#
# Md.: 3
# Oldest case: Johnson’s Lessee v. Kraner(1788-10)
# Link: https://api.case.law/v1/cases/1034759/
#
#
# N.J.: 2
# Oldest case: State v. Wells(1790-09)
# Link: https://api.case.law/v1/cases/321945/
#
#
# Va.: 3
# Oldest case: White v. Jones(1792-10)
# Link: https://api.case.law/v1/cases/1964199/
#
#
# Pa.: 9
# Oldest case: Clarke v. M‘Intire(1794-06)
# Link: https://api.case.law/v1/cases/12130675/
#
#
# U.S.: 11
# Oldest case: United States v. Bank of Alexandria(1801-04)
# Link: https://api.case.law/v1/cases/6639509/
#
#
# N.Y.: 3
# Oldest case: Mayell v. Potter(1801-10)
# Link: https://api.case.law/v1/cases/1890637/
#
#
# Ky.: 7
# Oldest case: Speed v. Lewis(1808)
# Link: https://api.case.law/v1/cases/6686656/
#
#
# Conn.: 7
# Oldest case: Hicock v. Hoskins(1809-06)
# Link: https://api.case.law/v1/cases/6753295/
#
#
# N.H.: 2
# Oldest case: Trustees of Dartmouth College v. Woodward(1817-11)
# Link: https://api.case.law/v1/cases/2361845/
#
#
# S.C.: 6
# Oldest case: Welch v. Phillips(1821-05)
# Link: https://api.case.law/v1/cases/8858741/
#
#
# N.C.: 3
# Oldest case: State v. Reed(1823-06)
# Link: https://api.case.law/v1/cases/11276857/
#
#
# Ala.: 3
# Oldest case: Jones v. Watkins(1827-01)
# Link: https://api.case.law/v1/cases/8493229/
#
#
# Tenn.: 8
# Oldest case: Vanzant v. Waddel(1829-01)
# Link: https://api.case.law/v1/cases/11266317/
#
#
# La.: 3
# Oldest case: Shepherd & Co. v. Lanfear(1833-03)
# Link: https://api.case.law/v1/cases/8749962/
#
#
# Del.: 2
# Oldest case: Hearn v. Ralph(1835)
# Link: https://api.case.law/v1/cases/1866284/
#
#
# Mo.: 5
# Oldest case: State ex rel. Gentry v. Fry(1835-08)
# Link: https://api.case.law/v1/cases/8853250/
#
#
# Mich.: 6
# Oldest case: United States v. Three Turkeys & A Basket of Salad(1836)
# Link: https://api.case.law/v1/cases/12097449/
#
#
# Miss.: 3
# Oldest case: Palmer v. Cross(1843-07)
# Link: https://api.case.law/v1/cases/1635125/
#
#
# Ill.: 7
# Oldest case: Rigg v. Cook(1847-12)
# Link: https://api.case.law/v1/cases/2563196/
#
#
# Ohio: 4
# Oldest case: Chesnut v. Shane’s Lessee(1847-12)
# Link: https://api.case.law/v1/cases/494383/
#
#
# Ga.: 3
# Oldest case: Rouse v. State(1848-01)
# Link: https://api.case.law/v1/cases/11075348/
#
#
# Fla.: 6
# Oldest case: Sibley v. Maria(1849-01)
# Link: https://api.case.law/v1/cases/8849708/
#
#
# Ark.: 7
# Oldest case: Biscoe v. Stone(1850-01)
# Link: https://api.case.law/v1/cases/8727394/
#
#
# Wis.: 2
# Oldest case: In re the County Seat of La Fayette County(1850-06)
# Link: https://api.case.law/v1/cases/6139952/
#
#
# Tex.: 3
# Oldest case: State v. Delesdenier(1851)
# Link: https://api.case.law/v1/cases/6767784/
#
#
# Ind.: 5
# Oldest case: City of Lafayette v. Cox(1854-05-23)
# Link: https://api.case.law/v1/cases/1448462/
#
#
# Cal.: 12
# Oldest case: People ex rel. Kohler v. Hays(1855)
# Link: https://api.case.law/v1/cases/2276005/
#
#
# Iowa: 2
# Oldest case: Miller v. Chittenden(1856-06)
# Link: https://api.case.law/v1/cases/2268318/
#
#
# R.I.: 1
# Oldest case: State v. Fitzpatrick(1856-09)
# Link: https://api.case.law/v1/cases/720692/
#
#
# Vt.: 1
# Oldest case: Keyes v. Hill(1858-08)
# Link: https://api.case.law/v1/cases/741818/
#
#
# Kan.: 4
# Oldest case: Parker v. Hays(1871-01)
# Link: https://api.case.law/v1/cases/90729/
#
#
# D.C.: 2
# Oldest case: Dainese v. Hale(1873-04)
# Link: https://api.case.law/v1/cases/2479659/
#
#
# Neb.: 5
# Oldest case: Sovereign v. State(1878-07)
# Link: https://api.case.law/v1/cases/5379066/
#
#
# Colo.: 2
# Oldest case: Martin v. McLaughlin(1880-12)
# Link: https://api.case.law/v1/cases/193375/
#
#
# Haw.: 3
# Oldest case: The King v. Manu(1881-04-22)
# Link: https://api.case.law/v1/cases/8826881/
#
#
# W. Va.: 16
# Oldest case: State v. Chambers(1883-10-27)
# Link: https://api.case.law/v1/cases/8641000/
#
#
# Mont.: 3
# Oldest case: Territory v. Hart(1888-01)
# Link: https://api.case.law/v1/cases/2282352/
#
#
# Me.: 2
# Oldest case: Moore v. Alden(1888-03-14)
# Link: https://api.case.law/v1/cases/487526/
#
#
# Or.: 9
# Oldest case: State v. Olds(1890-07-01)
# Link: https://api.case.law/v1/cases/8662364/
#
#
# Ariz.: 7
# Oldest case: Territory of Arizona v. Chartz(1893-01)
# Link: https://api.case.law/v1/cases/2887901/
#
#
# N.D.: 5
# Oldest case: Lay v. Emery(1899-07-01)
# Link: https://api.case.law/v1/cases/5296344/
#
#
# Okla.: 3
# Oldest case: Cameron v. Territory of Oklahoma(1906-02-15)
# Link: https://api.case.law/v1/cases/8879266/
#
#
# Wash.: 5
# Oldest case: Shepard v. Minneapolis Threshing Machine Co.(1908-08-17)
# Link: https://api.case.law/v1/cases/546021/
#
#
# Wyo.: 5
# Oldest case: State v. Kelley(1909-01-09)
# Link: https://api.case.law/v1/cases/8515974/
#
#
# Nev.: 5
# Oldest case: State v. Clark(1909-10)
# Link: https://api.case.law/v1/cases/8577250/
#
#
# Minn.: 5
# Oldest case: Sheehy v. Whipps(1913-06-06)
# Link: https://api.case.law/v1/cases/207851/
#
#
# S.D.: 2
# Oldest case: Dunlap v. Chicago, M. & St. P. Ry. Co.(1913-12-05)
# Link: https://api.case.law/v1/cases/8517904/
#
#
# N.M.: 2
# Oldest case: State v. Massey(1927-05-02)
# Link: https://api.case.law/v1/cases/1552968/
#
#
# Idaho: 2
# Oldest case: Lawson v. Robertson(1932-01-25)
# Link: https://api.case.law/v1/cases/2339209/
#
#
# Utah: 1
# Oldest case: Scoville v. Kellogg Sales Co.(1953-10-16)
# Link: https://api.case.law/v1/cases/62858/
#
#
# Alaska: 3
# Oldest case: Baker v. City of Fairbanks(1970-06-05)
# Link: https://api.case.law/v1/cases/10563444/
#
#
# V.I.: 1
# Oldest case: Saldana v. Kmart Corp.(1999-12-20)
# Link: https://api.case.law/v1/cases/233306/
